# %%
"""örnek bir öğrenci oluşturdum bu öğrenciyi kullanarak diğer öğrenci profillerini oluşturdum 
ve kullanıcıdan bu değerleri girmesini istedim"""
student={
        " student name":"Fadıl",
        "midterm grade":10,
        "project grade":10,
        "final grade":10
       
}
student1={}#5 tane öğrenci oluşturdum
student2={}
student3={}
student4={}
student5={}
listofmean=[]#burda öğrencilerin ortalamalarını depoluyacam alttaki ise geçici olarak kullanacağım bir dict
temp={}
listofstudent=[student1,student2,student3,student4,student5]
for x in range(0,len(listofstudent)):#öğrencilerin genel taslağını oluşturdum
    listofstudent[x]=student.copy()
for x in range(0,len(listofstudent)):   #kullanıcıdan öğrencinin verilerini girmesini istedim    
        temp=listofstudent[x].copy()
        for k,v in temp.items():  
          print("please enter",k)
          new=input()
          v=new
          temp[k]=new
        listofstudent[x]=temp.copy()
for x in range(0,len(listofstudent)):# her bir öğrencinin not ortalamasını hesaplayıp listenin içine attım
    listofmean.append(float(listofstudent[x]["midterm grade"])*0.3+float(listofstudent[x]["project grade"])*0.3+float(listofstudent[x]["final grade"])*0.4)
listofmean.sort()
listofmean.reverse()#burdaki 2 satırda ise büyükten küçüğe doğru sıraladım.
print(listofmean)
    
for x in range(0,len(listofstudent)):#daha uygun gözükmesi için tek tek bastırdım.
    print(listofstudent[x])
# Out:
# please enter  student name
# ali
# please enter midterm grade
# 50
# please enter project grade
# 30
# please enter final grade
# 60
# please enter  student name
# aslı
# please enter midterm grade
# 56
# please enter project grade
# 70
# please enter final grade
# 57
# please enter  student name
# Ayşe
# please enter midterm grade
# 68
# please enter project grade
# 90
# please enter final grade
# 90
# please enter  student name
# Fatih
# please enter midterm grade
# 30
# please enter project grade
# 40
# please enter final grade
# 20
# please enter  student name
# Emine
# please enter midterm grade
# 87
# please enter project grade
# 65
# please enter final grade
# 75
# [83.4, 75.6, 60.599999999999994, 48.0, 29.0]
# {' student name': 'ali', 'midterm grade': '50', 'project grade': '30', 'final grade': '60'}
# {' student name': 'aslı', 'midterm grade': '56', 'project grade': '70', 'final grade': '57'}
# {' student name': 'Ayşe', 'midterm grade': '68', 'project grade': '90', 'final grade': '90'}
# {' student name': 'Fatih', 'midterm grade': '30', 'project grade': '40', 'final grade': '20'}
# {' student name': 'Emine', 'midterm grade': '87', 'project grade': '65', 'final grade': '75'}
